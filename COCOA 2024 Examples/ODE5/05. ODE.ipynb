# %% [markdown]
# ![](../../logo.png)

# %% [markdown]
# # Physics Informed Neural Networks in Astrophysics
#
# ---
#
# ### Alexis Larrañaga - 2024
# ealarranaga@unal.edu.co
#
# ---

# %% [markdown]
# ## System of ODEs
#
# $$
# \begin{align}
# \frac{d^2 u}{dt^2} - \left(\frac{d u}{dt}\right)^2  = &0 \\
# \frac{d x}{dt} + \frac{d u}{dt} - x  = &0
# \end{align}
# $$
#
# Initial conditions:
# $$
# \begin{cases}
# u(t=0) = & 1\\
# u'(t=0) = & 0.5\\
# x(t=0) = & 1
# \end{cases}
# $$

# %%
import pinnde.ode_Solvers as ode_Solvers
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt


eqn1 = "utt - ut**2"
eqn2 = "xt + ut - x"
eqns = [eqn1, eqn2]
orders = [2, 1]
inits = [[1, 0.5], [1]]
t_bdry = [0,1]
N_pde = 100
epochs = 1000

mymodel = ode_Solvers.solveODE_System_IVP(eqns, orders, inits, t_bdry, N_pde, epochs)



mymodel.plot_epoch_loss('epoch_loss.png')

mymodel.plot_solution_prediction('solution.png')
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 40)        │         80 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 40)        │      1,640 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 40)        │      1,640 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 40)        │      1,640 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1)         │         41 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         41 │ dense_3[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,082 (19.85 KB)
#  Trainable params: 5,082 (19.85 KB)
#  Non-trainable params: 0 (0.00 B)
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# DE loss, IV loss in 0th epoch:  0.0764,  2.1005.
# DE loss, IV loss in 100th epoch:  0.0238,  0.0030.
# DE loss, IV loss in 200th epoch:  0.0102,  0.0024.
# DE loss, IV loss in 300th epoch:  0.0041,  0.0018.
# DE loss, IV loss in 400th epoch:  0.0018,  0.0017.
# DE loss, IV loss in 500th epoch:  0.0018,  0.0011.
# DE loss, IV loss in 600th epoch:  0.0015,  0.0014.
# DE loss, IV loss in 700th epoch:  0.0016,  0.0007.
# DE loss, IV loss in 800th epoch:  0.0015,  0.0005.
# DE loss, IV loss in 900th epoch:  0.0013,  0.0005.

# %%
plt.imshow(mpimg.imread('epoch_loss.png'))
plt.axis('off')
plt.show()

# %%
plt.imshow(mpimg.imread('solution.png'))
plt.axis('off')
plt.show()
